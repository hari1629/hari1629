# %% [markdown]
# <a href="https://colab.research.google.com/github/hari1629/hari1629/blob/main/chatbot_song_recommender_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install anvil-uplink
# Out:
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
import anvil.server

anvil.server.connect('server_H66R3XF3GTVOSOW7NP5BOCET-TKPKPS5J5VFLVANJ')
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default Environment" as SERVER

# %%
# pip install tensorflow keras pickle nltk
from google.colab import drive
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('/content/drive/MyDrive/Colab Notebooks/intents.json').read()
intents = json.loads(intents_file)

# %%
import shutil
shutil.rmtree('/root/nltk_data', ignore_errors=True)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')  # This is the specific missing resource
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# 1. First, reinstall NLTK to ensure clean installation
# !pip install --upgrade --force-reinstall nltk

# 2. Set the correct NLTK data path for Colab
import nltk
nltk.data.path.append('/root/nltk_data')

# 3. Download the required resources with force=True
nltk.download('punkt', force=True)
nltk.download('punkt_tab', force=True)

# 4. Verify the download
print("NLTK data paths:", nltk.data.path)
print("Punkt available:", nltk.data.find('tokenizers/punkt'))
print("Punkt_tab available:", nltk.data.find('tokenizers/punkt_tab'))

# 5. Now tokenize
from nltk.tokenize import word_tokenize
text = "Hello! How are you?"
print(word_tokenize(text))  # Should output: ['Hello', '!', 'How', 'are', 'you', '?']
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
# ...

# %%
import nltk
import json

# Force-download punkt tokenizer
nltk.download('punkt', force=True)

# Load intents
with open('/content/drive/MyDrive/Colab Notebooks/intents.json') as f:
    intents = json.load(f)

# Initialize data containers
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

# Process intents
for intent in intents['intents']:
    for pattern in intent['patterns']:
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        documents.append((word, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

print(documents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
import nltk
import numpy as np
import random
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()

# Make sure these are properly defined:
# classes = ["intent1", "intent2"]
# words = ["word1", "word2", ...]
# documents = [( ["token1", "token2"], "intent" ), ...]

training = []
output_empty = [0] * len(classes)

for doc in documents:
    # Lemmatize and lowercase
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in doc[0]]

    # Create bag of words
    bag = [1 if word in word_patterns else 0 for word in words]

    # Create output row
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# Shuffle and separate features/labels
random.shuffle(training)
train_x = np.array([x[0] for x in training])
train_y = np.array([x[1] for x in training])

print("Training data created successfully!")
print(f"Features shape: {train_x.shape}, Labels shape: {train_y.shape}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Training data created successfully!
# Features shape: (99, 226), Labels shape: (99, 21)

# %%
import numpy as np
import random
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint

# Download NLTK data
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Your data preparation code here...

# Deep Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train model
hist = model.fit(np.array(train_x), np.array(train_y),
                epochs=200,
                batch_size=5,
                verbose=1)

# Save model in modern format
model.save('chatbot_model.keras')  # Changed from .h5 to .keras
print("Model created and saved successfully in modern .keras format!")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0356 - loss: 3.0334
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1259 - loss: 2.9206
# Epoch 3/200
# ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('/content/chatbot_model.keras')
import json
import random
intents = json.loads(open('/content/drive/MyDrive/Colab Notebooks/intents.json').read())
words = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/words.pkl','rb'))
classes = pickle.load(open('/content/drive/MyDrive/Colab Notebooks/classes.pkl','rb'))
def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)
    return(np.array(bag))
def predict_class(sentence):
    # filter below  threshold predictions
    p = bag_of_words(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

# Initialize NLTK
nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

# Load intents
with open('/content/drive/MyDrive/Colab Notebooks/intents.json') as file:
    intents = json.load(file)

words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

# Process intents
for intent in intents['intents']:
    for pattern in intent['patterns']:
        # Tokenize each word
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatize and clean words
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in ignore_letters]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

# Save words and classes
with open('words.pkl', 'wb') as f:
    pickle.dump(words, f)
with open('classes.pkl', 'wb') as f:
    pickle.dump(classes, f)

# Create training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in doc[0]]

    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# Shuffle and prepare training data
random.shuffle(training)
train_x = np.array([x[0] for x in training])
train_y = np.array([x[1] for x in training])

# Verify dimensions
print(f"Vocabulary size: {len(words)}")
print(f"Number of classes: {len(classes)}")
print(f"Training data shape: {train_x.shape}")

# Create model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train model
history = model.fit(train_x, train_y, epochs=172, batch_size=5, verbose=1)

# Save model in both formats
model.save('chatbot_model.h5')  # Legacy format
model.save('chatbot_model.keras')  # Recommended format

print("Model created and saved successfully!")
print(f"Final training accuracy: {history.history['accuracy'][-1]:.2f}")
# Out:
# Vocabulary size: 113
# Number of classes: 21
# Training data shape: (99, 113)
# Epoch 1/172
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0445 - loss: 3.0518
# Epoch 2/172
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0997 - loss: 3.0276
# Epoch 3/172
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0913 - loss: 2.9954
# Epoch 4/172
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0849 - loss: 2.8949
# Epoch 5/172
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0974 - loss: 2.8388
# Epoch 6/172
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1546 - loss: 2.8427
# Epoch 7/172
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2559 - loss: 2.6825
# Epoch 8/172
# ...

# %%
# !pip install --upgrade ibm-watson
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.8/342.8 kB 9.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 4.4 MB/s eta 0:00:00
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-9.0.0-py3-none-any.whl size=345069 sha256=9be7ae9d9028c1be7d61831883f21513e6ee8e71381783747cbaf58f0eb07f5a
#   Stored in directory: /root/.cache/pip/wheels/a1/ed/65/5abe3aa86c063331a8064910b7722d22ddf0bd75fc322f6c48
# Successfully built ibm-watson
# ...

# %%
import anvil.server

# %%
# !pip show ibm-watson
# Out:
# Name: ibm-watson
# Version: 9.0.0
# Summary: Client library to use the IBM Watson Services
# Home-page: https://github.com/watson-developer-cloud/python-sdk
# Author: IBM Watson
# Author-email: watdevex@us.ibm.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: ibm_cloud_sdk_core, python_dateutil, requests, websocket-client
# Required-by:

# %%
anvil.server.connect('server_H66R3XF3GTVOSOW7NP5BOCET-TKPKPS5J5VFLVANJ')
# Out:
# Connecting to wss://anvil.works/uplink
# Anvil websocket open
# Connected to "Default Environment" as SERVER

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, SentimentOptions

# Set up authenticator
authenticator = IAMAuthenticator('39lXcSMn-QhbkrbREgsHl2NEQI0SQJKMxGRa6OMPBNT9')

# Create NLU instance
nlu = NaturalLanguageUnderstandingV1(
    version='2022-04-07',  # Use the latest version available
    authenticator=authenticator
)

nlu.set_service_url('https://api.jp-tok.natural-language-understanding.watson.cloud.ibm.com/instances/59427287-9b7e-45b1-99e8-5d9d7ed4cc37')

# Example analysis
response = nlu.analyze(
    text="I love this product! It's amazing, though a bit expensive.",
    features=Features(sentiment=SentimentOptions())
).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 58,
#     "features": 1
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.959139,
#       "label": "positive"
#     }
#   },
#   "language": "en"
# }

# %%
msg = list()
text = str()

# %%
@anvil.server.callable
def responsed(msg1):
    msg.append(msg1)
    ints = predict_class(msg1)
    res = getResponse(ints, intents)
    return res

# %%
# # IBM Tone analyzer
# import json
# from ibm_watson import ToneAnalyzerV3
# from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# authenticator = IAMAuthenticator(api_key)
# tone_analyzer = ToneAnalyzerV3(
#     version='2017-09-21',
#     authenticator=authenticator
# )

# tone_analyzer.set_service_url(https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/api_key)
# text = " "
# for i in msg:
#     text = text+i
# tone_analysis = tone_analyzer.tone(
#     {'text': text},
#     content_type='application/json'
# ).get_result()
# print(json.dumps(tone_analysis, indent=2))

# %%
@anvil.server.callable
def song_emotion():
    # Initialize default response with emotion
    default_response = {
        'emotion': 'happy',  # Default fallback emotion
        'error': None
    }

    # IBM Watson NLU Authentication
    authenticator = IAMAuthenticator("39lXcSMn-QhbkrbREgsHl2NEQI0SQJKMxGRa6OMPBNT9")
    nlu = NaturalLanguageUnderstandingV1(
        version='2022-04-07',
        authenticator=authenticator
    )
    nlu.set_service_url("https://api.jp-tok.natural-language-understanding.watson.cloud.ibm.com/instances/59427287-9b7e-45b1-99e8-5d9d7ed4cc37")

    # Get last 5 messages (handle empty case)
    if not msg:
        default_response['error'] = "No messages available"
        return default_response

    text_to_analyze = " ".join(msg[-5:])  # Last 5 messages

    try:
        # Analyze emotion using NLU
        emotion_response = nlu.analyze(
            text=text_to_analyze,
            features=Features(emotion=EmotionOptions())
        ).get_result()

        # Get dominant emotion
        emotions = emotion_response['emotion']['document']['emotion']
        dominant_emotion = max(emotions.items(), key=lambda x: x[1])[0]

        # Map to Last.fm compatible tags
        emotion_map = {
            'joy': 'happy',
            'anger': 'angry',
            'sadness': 'sad',
            'fear': 'melancholic',
            'disgust': 'dark'
        }
        lastfm_tag = emotion_map.get(dominant_emotion, dominant_emotion)

        # Get tracks from Last.fm
        response_dict = {'emotion': dominant_emotion}
        last_fm_url = f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={lastfm_tag}&api_key=dd897931f0abc1282fb47ff9865473cb&format=json&limit=10"
        response = requests.get(last_fm_url)

        if response.status_code != 200:
            raise Exception("Last.fm API request failed")

        payload = response.json()

        # Check if tracks exist
        if 'tracks' not in payload or 'track' not in payload['tracks']:
            raise Exception("No tracks found in Last.fm response")

        # Add tracks to response
        for i, track in enumerate(payload['tracks']['track'][:10]):  # Max 10 tracks
            response_dict[track['name']] = track['url']

        return response_dict

    except Exception as e:
        # Return default happy songs + error info
        default_response['error'] = str(e)

        # Add some default happy songs (fallback)
        default_response.update({
            "Happy Song 1": "https://example.com/song1",
            "Happy Song 2": "https://example.com/song2"
        })

        return default_response

# %%
# print(msg)
# # print(text)
# print(len(msg))

# %%
# SONG RECOMMENDATION

# %%
import requests

# Last.fm API configuration
LAST_FM_API_KEY = "dd897931f0abc1282fb47ff9865473cb"  # Your Last.fm API key
BASE_URL = "http://ws.audioscrobbler.com/2.0/"

def get_top_tracks(tag="happy", limit=5):
    """
    Get top tracks by tag from Last.fm API

    Args:
        tag (str): Mood/emotion tag (e.g., 'happy', 'sad')
        limit (int): Number of tracks to return (1-100)

    Returns:
        dict: Contains track information or error message
    """
    params = {
        "method": "tag.gettoptracks",
        "tag": tag,
        "api_key": LAST_FM_API_KEY,
        "format": "json",
        "limit": limit
    }

    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()  # Raise exception for HTTP errors
        data = response.json()

        # Process and return track data
        tracks = []
        for track in data.get("tracks", {}).get("track", []):
            tracks.append({
                "name": track.get("name", "Unknown Track"),
                "artist": track.get("artist", {}).get("name", "Unknown Artist"),
                "url": track.get("url", "#"),
                "image": [img.get("#text", "") for img in track.get("image", [])]
            })

        return {
            "status": "success",
            "tag": tag,
            "tracks": tracks
        }

    except requests.exceptions.RequestException as e:
        return {"status": "error", "message": f"API request failed: {str(e)}"}
    except ValueError as e:
        return {"status": "error", "message": f"Invalid JSON response: {str(e)}"}

# Example usage
if __name__ == "__main__":
    result = get_top_tracks(tag="happy", limit=5)
    print(result)
# Out:
# {'status': 'success', 'tag': 'happy', 'tracks': [{'name': 'Pumped Up Kicks', 'artist': 'Foster the People', 'url': 'https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks', 'image': ['https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png']}, {'name': 'Hey Ya!', 'artist': 'OutKast', 'url': 'https://www.last.fm/music/OutKast/_/Hey+Ya%21', 'image': ['https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png', 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png', 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png', 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png']}, {'name': 'Dog Days Are Over', '
# ...

# %%
# print(dic1)

# %%
import requests

def get_top_tracks_by_mood(emotion='happy', limit=5):
    """
    Fetches top tracks from Last.fm based on mood/emotion

    Args:
        emotion (str): Emotion tag (e.g., 'happy', 'sad')
        limit (int): Number of tracks to return (1-100)

    Returns:
        dict: Track information or error message
    """
    api_key = 'dd897931f0abc1282fb47ff9865473cb'  # Your Last.fm API key

    try:
        # Make the API request
        url = f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={emotion}&api_key={api_key}&format=json&limit={limit}"
        response = requests.get(url)
        response.raise_for_status()  # Raises exception for HTTP errors

        payload = response.json()

        # Validate and extract track data
        if 'tracks' not in payload or 'track' not in payload['tracks']:
            return {'error': 'Invalid response format from Last.fm'}

        # Extract relevant track information
        tracks = []
        for track in payload['tracks']['track'][:limit]:
            tracks.append({
                'name': track.get('name', 'Unknown'),
                'artist': track.get('artist', {}).get('name', 'Unknown'),
                'url': track.get('url', '#'),
                'image': track.get('image', [{}])[-1].get('#text', '')  # Get largest image
            })

        return {
            'status': 'success',
            'emotion': emotion,
            'tracks': tracks
        }

    except requests.exceptions.RequestException as e:
        return {'error': f'API request failed: {str(e)}'}
    except ValueError as e:
        return {'error': f'Invalid JSON response: {str(e)}'}
    except Exception as e:
        return {'error': f'Unexpected error: {str(e)}'}

# Example usage
if __name__ == '__main__':
    result = get_top_tracks_by_mood(emotion='happy', limit=5)
    print(result)
# Out:
# {'status': 'success', 'emotion': 'happy', 'tracks': [{'name': 'Pumped Up Kicks', 'artist': 'Foster the People', 'url': 'https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks', 'image': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png'}, {'name': 'Hey Ya!', 'artist': 'OutKast', 'url': 'https://www.last.fm/music/OutKast/_/Hey+Ya%21', 'image': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png'}, {'name': 'Dog Days Are Over', 'artist': 'Florence + the Machine', 'url': 'https://www.last.fm/music/Florence+%252B+the+Machine/_/Dog+Days+Are+Over', 'image': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png'}, {'name': "Friday I'm in Love", 'artist': 'The Cure', 'url': 'https://www.last.fm/music/The+Cure/_/Friday+I%27m+in+Love', 'image': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png'}, {'name': "I'm Yours", 'artist': 'Jason Mraz', 'url': 'https://w
# ...

# %%
print("Chatbot : Hey there, Wassup ?")
# responded function takes text of user and returns chatbot output
for i in range(5):
    m = input("User : ")
    res = responsed(m)
    print("Chatbot : "+res)
ans = song_emotion()
print("Emotion : "+ans['emotion'])
# Out:
# Chatbot : Hey there, Wassup ?
# User : Today is my birthday, what is your age?
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Chatbot : I can't know my age if I'm on a computer...
# User : oh! I am in a good mood today, how are you
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Chatbot : Im enjoying our conversation!
# User : I am good, you are nice
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Chatbot : Youre pretty cool yourself!
# User : Thank you, what is your name
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Chatbot : Im not named yet, but I was thinking about calling myself Alex. Doesnt that sound nice?
# User : yes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Chatbot : Yep, I like how it sounds. I got it from the Terminator.
# Emotion : happy

# %%
ans = song_emotion()
print("Emotion : "+ans['emotion'])
ans.pop('emotion')
lst = list(ans.keys())
print("Song Recommendations : ")
for i in range(10):
    print("Song_name : "+lst[i])
    print("Song_URL : "+ans[lst[i]])
# Out:
# Emotion : happy
# Song Recommendations :
# Song_name : Pumped Up Kicks
# Song_URL : https://www.last.fm/music/Foster+the+People/_/Pumped+Up+Kicks
# Song_name : Hey Ya!
# Song_URL : https://www.last.fm/music/OutKast/_/Hey+Ya%21
# Song_name : Dog Days Are Over
# Song_URL : https://www.last.fm/music/Florence+%252B+the+Machine/_/Dog+Days+Are+Over
# Song_name : Friday I'm in Love
# Song_URL : https://www.last.fm/music/The+Cure/_/Friday+I%27m+in+Love
# Song_name : I'm Yours
# Song_URL : https://www.last.fm/music/Jason+Mraz/_/I%27m+Yours
# Song_name : Island in the Sun
# Song_URL : https://www.last.fm/music/Weezer/_/Island+in+the+Sun
# Song_name : A-Punk
# Song_URL : https://www.last.fm/music/Vampire+Weekend/_/A-Punk
# Song_name : espresso
# Song_URL : https://www.last.fm/music/Sabrina+Carpenter/_/espresso
# Song_name : Kiss Me
# Song_URL : https://www.last.fm/music/Sixpence+None+the+Richer/_/Kiss+Me
# Song_name : My Love Mine All Mine
# ...
